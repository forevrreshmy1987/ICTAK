# %% [markdown]
# <a href="https://colab.research.google.com/github/forevrreshmy1987/ICTAK/blob/main/Virtual_competition_1_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5,np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(data,index=labels[:])
df.fillna(value = 0, inplace = True)

df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  0.0       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  0.0       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
df.describe()
# Out:
#              age     visits
# count  10.000000  10.000000
# mean    2.750000   1.900000
# std     2.288255   0.875595
# min     0.000000   1.000000
# 25%     0.875000   1.000000
# 50%     2.750000   2.000000
# 75%     4.125000   2.750000
# max     7.000000   3.000000

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 2  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
df[['animal', 'age']]
# Out:
#   animal  age
# 0    cat  2.5
# 1    cat  3.0
# 2  snake  0.5
# 3    dog  0.0
# 4    dog  5.0
# 5    cat  2.0
# 6  snake  4.5
# 7    cat  0.0
# 8    dog  7.0
# 9    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
df.iloc[[3, 4, 8], [0, 1]]
# Out:
#   animal  age
# 3    dog  0.0
# 4    dog  5.0
# 8    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
df.where(df['visits']>3)
# Out:
#   animal  age  visits priority
# 0    NaN  NaN     NaN      NaN
# 1    NaN  NaN     NaN      NaN
# 2    NaN  NaN     NaN      NaN
# 3    NaN  NaN     NaN      NaN
# 4    NaN  NaN     NaN      NaN
# 5    NaN  NaN     NaN      NaN
# 6    NaN  NaN     NaN      NaN
# 7    NaN  NaN     NaN      NaN
# 8    NaN  NaN     NaN      NaN
# 9    NaN  NaN     NaN      NaN

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5,np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df1 = pd.DataFrame(data,index=labels[:])
check_nan = df1['age'].isnull().values.any()

# printing the result
print(check_nan)
# Out:
# True

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5,np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(data,index=labels[:])
index=(labels)
df[(df['animal'] =='cat') & (df['age']<3)]
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 5    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
df[(df['age'] >= 2) &(df['age']<=4)]
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 5    cat  2.0       3       no
# 9    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df.loc['f', 'age'] = 1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  0.0       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  0.0       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5,np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df.groupby(['visits']).size().to_frame('count').reset_index().sort_values('visits',ascending=True)
# Out:
#    visits  count
# 0       1      4
# 1       2      3
# 2       3      3

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.5
# dog      5.0
# snake    2.5
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
df.loc['k'] = ['squirrel', 7.5, 'no', 10]
print(df)
# and then deleting the new row...

df = df.drop('k')
print(df)
# Out:
#      animal  age visits priority
# a       cat  2.5      1      yes
# b       cat  3.0      3      yes
# c     snake  0.5      2       no
# d       dog  NaN      3      yes
# e       dog  5.0      2       no
# f       cat  2.0      3       no
# g     snake  4.5      1       no
# h       cat  NaN      1      yes
# i       dog  7.0      2       no
# j       dog  3.0      1       no
# k  squirrel  7.5     no       10
#   animal  age visits priority
# a    cat  2.5      1      yes
# b    cat  3.0      3      yes
# c  snake  0.5      2       no
# d    dog  NaN      3      yes
# e    dog  5.0      2       no
# f    cat  2.0      3       no
# g  snake  4.5      1       no
# h    cat  NaN      1      yes
# i    dog  7.0      2       no
# j    dog  3.0      1       no

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
df.groupby('animal').size().to_frame('count').reset_index()
# Out:
#   animal  count
# 0    cat      4
# 1    dog      4
# 2  snake      2

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
import pandas as pd
import numpy as np

df1 = df.sort_values(by=['age','visits'], ascending=[False, True])
df
# Out:
#    animal  age  visits priority
# a     cat  2.5       1      yes
# b     cat  3.0       3      yes
# c  python  0.5       2       no
# d     dog  0.0       3      yes
# e     dog  5.0       2       no
# f     cat  1.5       3       no
# g  python  4.5       1       no
# h     cat  0.0       1      yes
# i     dog  7.0       2       no
# j     dog  3.0       1       no

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df = df.astype({'priority': 'bool'})
df.loc[df['priority'] == 'yes', 'priority'] = True
df.loc[df['priority'] == ' no', 'priority'] = False

print(df)
# Out:
#   animal  age visits  priority
# a    cat  2.5      1      True
# b    cat  3.0      3      True
# c  snake  0.5      2      True
# d    dog  NaN      3      True
# e    dog  5.0      2      True
# f    cat  2.0      3      True
# g  snake  4.5      1      True
# h    cat  NaN      1      True
# i    dog  7.0      2      True
# j    dog  3.0      1      True

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df.loc[df['animal'] == 'snake', 'animal'] = 'python'
df
# Out:
#    animal  age  visits priority
# a     cat  2.5       1      yes
# b     cat  3.0       3      yes
# c  python  0.5       2       no
# d     dog  0.0       3      yes
# e     dog  5.0       2       no
# f     cat  1.5       3       no
# g  python  4.5       1       no
# h     cat  0.0       1      yes
# i     dog  7.0       2       no
# j     dog  3.0       1       no

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
for this question i did it from my company lap so the security settings does not allow us to upload the different files other than company files
 Please excuse
# Out:
#   File "<ipython-input-27-bb333140f8d4>", line 4
#     df3 = pd.read_csv("C:\Users\2335743\Downloads\ny-flights (2).csv")
#                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay
